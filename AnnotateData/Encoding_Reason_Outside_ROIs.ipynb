# %% [markdown]
# In this notebook, I want to encode the reason for things being outside of ROIs systematically. Hopefully I can do this somehow.

# %%
options(repr.matrix.max.rows = 500, repr.matrix.max.cols = 500)

# %%
recgli = read.csv("../ParseData/4thParse_researchPath_withInVivo.csv")

# %%
dim(recgli)
# Out:
# [1] 545  72

# %%
table(recgli$in_ROI)
# Out:
#   0   1
#  89 456

# %%
recgli[recgli$in_ROI == 0,]
# Out:
#     b_number t_number sf_number current_scan_date current_surgery_date
# 3   2901      8089     8403     6/25/10           6/30/10
# 4   2474      7408     8701     3/23/11           3/24/11
# 9   2901      8089     8403     6/25/10           6/30/10
# 10  2474      7408     8701     3/23/11           3/24/11
# 12  2901      8089     8403     6/25/10           6/30/10
# 13  3118      7394     8688     3/15/11           3/16/11
# 14  2873      6709     8269     3/11/10           3/15/10
# 15  3118      7394     8688     3/15/11           3/16/11
# 16  2793      7584     8842     7/28/11           7/28/11
# 18  2873      6709     8269     3/11/10           3/15/10
# 29  3012      7111     8521     10/18/10          10/19/10
# 37  2571      7444     8722     4/14/11           4/15/11
# 38  2571      7444     8722     4/14/11           4/15/11
# 39  2571      7444     8722     4/14/11           4/15/11
# 40  3171      7553     8804     6/24/11           6/27/11
# ...

# %%
## Let's start w/ those WITH igt_stats output that are not in the ROI at all, e.g. sum == 0: 
dim(recgli[which(recgli$sum == 0 & recgli$in_ROI==0),])
# Out:
# [1] 15 72

# %%
recgli[which(recgli$sum == 0 & recgli$in_ROI==1),]
# Out:
#     b_number t_number sf_number current_scan_date current_surgery_date
# 22  2192      8070     7540     11/18/07          11/19/07
# 119 1693      5550     7732     7/8/08            7/9/08
# 144 2769      7225     8582     12/16/10          12/17/10
# 175 2382      5577     7750     7/22/08           7/23/08
# 191 2437      5880     7894     12/17/08          12/19/08
# 192 2437      5880     7894     12/17/08          12/19/08
# 248 2415      5668     7793     9/2/08            9/3/08
# 290 3472      8783     9739     2013-10-14        2013-10-15
# 468 4253     11218    11163     2017-02-07        2017-02-08
#     current_hist_grade current_hist_type roi.label tumor_cell_evaluation
# 22  Grade IV           Glioblastoma      18B13     3
# 119 Grade IV           Glioblastoma      56B17     3
# 144 Treatment Effect   Treatment Effect  62B39     0
# 175 Grade IV           Glioblastoma      73B17     1
# 191 Treatment Effect   Treatment Effect  7894a     0
# ...
