# %%
## Train/Test split:

# %%
library(caret)
options(repr.matrix.max.rows=600, repr.matrix.max.cols=200)

# %%
recgli = read.csv("../../ParseData/8thParse_researchPath_withInVivo.csv")

# %%
dim(recgli)
# Out:
# [1] 391  74

# %%
## we want to iteratively split & write data

# %%
train_dir = "/home/sf673542/DataWrangling/AnalyzeData/AllBiopsies/Training/"
test_dir = "/home/sf673542/DataWrangling/AnalyzeData/AllBiopsies/Testing/"

# %%
tnum_list = recgli$t_number[which(!duplicated(recgli$t_number))]

# %%
for (i in 1:1000){
    set.seed(i)
    train = sample(1:162, 162*.75)
    tnum_list_train = tnum_list[train]
    tnum_list_test = tnum_list[-train]
    data_train = recgli[recgli$t_number %in% tnum_list_train,]
    data_test = recgli[recgli$t_number %in% tnum_list_test,]
    filename_train = paste(train_dir, 'train_data_', i, '.csv', sep='')
    filename_test = paste(test_dir, 'test_data_', i, '.csv', sep='')
    write.csv(data_train, file=filename_train, row.names = F)
    write.csv(data_test, file = filename_test, row.names = F)
}

# %%
## Impute using various algorithms & Look at the quality of imputation:

# %% [markdown]
# According to some references (listed below), closest match imputation is best for repeated measures data; however, this is really for time series. We can try some other imputation methods as well. <br>
# 1. mice.impute.2l.lmer -
# 2. Closest Match Imputation - mice.impute.pmm() finds matches among the observed data in the predictive mean metric. It selects the donors closest matches, randomly samples one of the donors, and returns the observed value of the match.
# 3. Predictive Mean Matching

# %%
## median imputation:

# %%
library(mice)
library(ggplot2)
library(lattice)
library(Amelia)
# Out:
# Warning message:
# “package ‘Amelia’ was built under R version 3.4.1”Loading required package: Rcpp
# ##
# ## Amelia II: Multiple Imputation
# ## (Version 1.7.5, built: 2018-05-07)
# ## Copyright (C) 2005-2018 James Honaker, Gary King and Matthew Blackwell
# ## Refer to http://gking.harvard.edu/amelia/ for more information
# ##

# %%
methods(mice)
# Out:
# Warning message in .S3methods(generic.function, class, parent.frame()):
# “function 'mice' appears not to be S3 generic; found functions that look like S3 methods”
#  [1] mice.impute.2l.bin       mice.impute.2l.lmer      mice.impute.2l.norm
#  [4] mice.impute.2l.pan       mice.impute.2lonly.mean  mice.impute.2lonly.norm
#  [7] mice.impute.2lonly.pmm   mice.impute.cart         mice.impute.jomoImpute
# [10] mice.impute.lda          mice.impute.logreg       mice.impute.logreg.boot
# [13] mice.impute.mean         mice.impute.midastouch   mice.impute.norm
# [16] mice.impute.norm.boot    mice.impute.norm.nob     mice.impute.norm.predict
# [19] mice.impute.panImpute    mice.impute.passive      mice.impute.pmm
# [22] mice.impute.polr         mice.impute.polyreg      mice.impute.quadratic
# [25] mice.impute.rf           mice.impute.ri           mice.impute.sample
# [28] mice.mids                mice.theme
# see '?methods' for accessing help and source code

# %%
## preparing for imputation using mice: vars <- colnames(dat1)
data.frame(index = 1:length(colnames(recgli)), colnames_recgli = colnames(recgli))
include_vars = colnames(recgli)[c(16:44,65,67,68,69)]
include_vars
# Out:
#    index colnames_recgli
# 1   1    b_number
# 2   2    t_number
# 3   3    sf_number
# 4   4    current_scan_date
# 5   5    current_surgery_date
# 6   6    current_hist_grade
# 7   7    current_hist_type
# 8   8    roi.label
# 9   9    tumor_cell_evaluation
# 10 10    necrosis
# 11 11    f8_delicate
# 12 12    f8_simple
# 13 13    f8_complex
# 14 14    mib_1
# 15 15    bx_pure_treatment_effect
# 16 16    nfse
# 17 17    nfl
# 18 18    nt1c
# 19 19    nt1v
# 20 20    nadc.1
# 21 21    nfa.1
# 22 22    nev1.1
# 23 23    nev2.1
# 24 24    nev3.1
# 25 25    nevrad.1
# 26 26    nadc.2
# 27 27    nfa.2
# 28 28    nev1.2
# 29 29    nev2.2
# 30 30    nev3.2
# 31 31    nevrad.2
# 32 32    cbvn_nlin
# 33 33    phn_nlin
# 34 34    phn_npar
# 35 35    recovn_npar
# 36 36    cni
# 37 37    ccri
# 38 38    crni
# 39 39    ncho
# 40 40    ncre
# 41 41    nnaa
# 42 42    nlip
# 43 43    laclip
# 44 44    nlac
# 45 45    olddata
# 46 46    newdata
# 47 47    comments
# 48 48    notes.
# 49 49    imaging_code
# 50 50    perf_quant
# 51 51    cbv_nlin
# 52 52    spec_quant
# 53 53    include_anat
# 54 54    include_diffu1000
# 55 55    include_diffu2000
# 56 56    include_diffu_all
# 57 57    include_perf
# 58 58    include_spec
# 59 59    include_one_advanced_mod
# 60 60    include_all_advanced_mods
# 61 61    X.CEL
# 62 62    X.NEL
# 63 63    X.NEC
# 64 64    sum
# 65 65    in_CEL
# 66 66    in_T2all
# 67 67    in_NEL
# 68 68    in_NEC
# 69 69    in_ROI
# 70 70    desired_hist
# 71 71    multnom_out
# 72 72    no_ffpe
# 73 73    waiting_on_path
# 74 74    rhgg_txe_analysis
#  [1] "nfse"        "nfl"         "nt1c"        "nt1v"        "nadc.1"
#  [6] "nfa.1"       "nev1.1"      "nev2.1"      "nev3.1"      "nevrad.1"
# [11] "nadc.2"      "nfa.2"       "nev1.2"      "nev2.2"      "nev3.2"
# [16] "nevrad.2"    "cbvn_nlin"   "phn_nlin"    "phn_npar"    "recovn_npar"
# [21] "cni"         "ccri"        "crni"        "ncho"        "ncre"
# [26] "nnaa"        "nlip"        "laclip"      "nlac"        "in_CEL"
# [31] "in_NEL"      "in_NEC"      "in_ROI"

# %%
missmap(recgli, col=c('grey', 'steelblue'), y.cex=0.5, x.cex=0.5)
# Out:
# Plot with title “Missingness Map”

# %%
sort(sapply(recgli, function(x) { sum(is.na(x)) }), decreasing=TRUE)
# Out:
#              imaging_code                  cbv_nlin                    notes.
#                       391                       391                       385
#                     X.NEC                       cni                      ccri
#                       306                       219                       219
#                      crni                      ncho                      ncre
#                       219                       219                       219
#                      nnaa                      nlip                    laclip
#                       219                       219                       219
#                      nlac                spec_quant                  phn_nlin
#                       219                       189                       173
#                  phn_npar               recovn_npar                    nev1.2
#                       173                       173                       170
#                    nev2.2                    nev3.2                  nevrad.2
#                       170                       170                       170
#                    nadc.2                     nfa.2                 cbvn_nlin
#                       120                       119                        89
#                     X.CEL                      nt1v                     X.NEL
#                        68                        63                        60
#                       sum                    nev1.1                    nev2.1
#                        58                        48                        48
#                    nev3.1                  nevrad.1                     nfa.1
#                        48                        48                        23
#                     mib_1                    nadc.1                       nfl
#                        11                         8                         3
#                  b_number                  t_number                 sf_number
#                         0                         0                         0
#         current_scan_date      current_surgery_date        current_hist_grade
#                         0                         0                         0
#         current_hist_type                 roi.label     tumor_cell_evaluation
#                         0                         0                         0
#                  necrosis               f8_delicate                 f8_simple
#                         0                         0                         0
#                f8_complex  bx_pure_treatment_effect                      nfse
#                         0                         0                         0
#                      nt1c                   olddata                   newdata
#                         0                         0                         0
#                  comments                perf_quant              include_anat
#                         0                         0                         0
#         include_diffu1000         include_diffu2000         include_diffu_all
#                         0                         0                         0
#              include_perf              include_spec  include_one_advanced_mod
#                         0                         0                         0
# include_all_advanced_mods                    in_CEL                  in_T2all
#                         0                         0                         0
#                    in_NEL                    in_NEC                    in_ROI
#                         0                         0                         0
#              desired_hist               multnom_out                   no_ffpe
#                         0                         0                         0
#           waiting_on_path         rhgg_txe_analysis
#                         0                         0

# %%
include_vars
exclude_vars = setdiff(names(recgli), include_vars)
exclude_vars
# Out:
#  [1] "nfse"        "nfl"         "nt1c"        "nt1v"        "nadc.1"
#  [6] "nfa.1"       "nev1.1"      "nev2.1"      "nev3.1"      "nevrad.1"
# [11] "nadc.2"      "nfa.2"       "nev1.2"      "nev2.2"      "nev3.2"
# [16] "nevrad.2"    "cbvn_nlin"   "phn_nlin"    "phn_npar"    "recovn_npar"
# [21] "cni"         "ccri"        "crni"        "ncho"        "ncre"
# [26] "nnaa"        "nlip"        "laclip"      "nlac"        "in_CEL"
# [31] "in_NEL"      "in_NEC"      "in_ROI"
#  [1] "b_number"                  "t_number"
#  [3] "sf_number"                 "current_scan_date"
#  [5] "current_surgery_date"      "current_hist_grade"
#  [7] "current_hist_type"         "roi.label"
#  [9] "tumor_cell_evaluation"     "necrosis"
# [11] "f8_delicate"               "f8_simple"
# [13] "f8_complex"                "mib_1"
# [15] "bx_pure_treatment_effect"  "olddata"
# [17] "newdata"                   "comments"
# [19] "notes."                    "imaging_code"
# [21] "perf_quant"                "cbv_nlin"
# [23] "spec_quant"                "include_anat"
# [25] "include_diffu1000"         "include_diffu2000"
# [27] "include_diffu_all"         "include_perf"
# [29] "include_spec"              "include_one_advanced_mod"
# [31] "include_all_advanced_mods" "X.CEL"
# [33] "X.NEL"                     "X.NEC"
# [35] "sum"                       "in_T2all"
# [37] "desired_hist"              "multnom_out"
# [39] "no_ffpe"                   "waiting_on_path"
# [41] "rhgg_txe_analysis"

# %%
recgli_toimp=recgli[include_vars]

# %%
impmeth <- rep("",length(include_vars))
names(impmeth) <- include_vars
impmeth[1:29] <- "mice.impute.2l.lmer"
impmeth[30:33] <-'mice.impute.21.bin'
impmeth
# Out:
#                  nfse                   nfl                  nt1c
# "mice.impute.2l.lmer" "mice.impute.2l.lmer" "mice.impute.2l.lmer"
#                  nt1v                nadc.1                 nfa.1
# "mice.impute.2l.lmer" "mice.impute.2l.lmer" "mice.impute.2l.lmer"
#                nev1.1                nev2.1                nev3.1
# "mice.impute.2l.lmer" "mice.impute.2l.lmer" "mice.impute.2l.lmer"
#              nevrad.1                nadc.2                 nfa.2
# "mice.impute.2l.lmer" "mice.impute.2l.lmer" "mice.impute.2l.lmer"
#                nev1.2                nev2.2                nev3.2
# "mice.impute.2l.lmer" "mice.impute.2l.lmer" "mice.impute.2l.lmer"
#              nevrad.2             cbvn_nlin              phn_nlin
# "mice.impute.2l.lmer" "mice.impute.2l.lmer" "mice.impute.2l.lmer"
#              phn_npar           recovn_npar                   cni
# "mice.impute.2l.lmer" "mice.impute.2l.lmer" "mice.impute.2l.lmer"
#                  ccri                  crni                  ncho
# "mice.impute.2l.lmer" "mice.impute.2l.lmer" "mice.impute.2l.lmer"
#                  ncre                  nnaa                  nlip
# "mice.impute.2l.lmer" "mice.impute.2l.lmer" "mice.impute.2l.lmer"
#                laclip                  nlac                in_CEL
# "mice.impute.2l.lmer" "mice.impute.2l.lmer"  "mice.impute.21.bin"
#                in_NEL                in_NEC                in_ROI
#  "mice.impute.21.bin"  "mice.impute.21.bin"  "mice.impute.21.bin"

# %%
recgli_imp = mice(recgli_toimp, imputationMethod = impmeth, printFlag = F, m = 5, maxit = 1 )
# Out:
# Warning message:
# “Number of logged events: 1”
