# %% [markdown]
# In this notebook, we want to summarize the data and make sure that it is behaving as we expect based on previous literature. Here, we want to only use the outcome for tumor_cell_evaluation

# %% [markdown]
# Tumor score is defined by UCSF pathologists in the following way: <br>
#
# 0: neuropil without tumor <br>
# 1: infiltrating tumor margin containing a detectable but not abundant number of tumor cells <br>
# 2: more cellular infiltrated zone <br>
# 3: highly cellular tumor <br>

# %%
recgli = read.csv("../../ParseData/8thParse_researchPath_withInVivo.csv")

# %%
data.frame(recgli$b_number, recgli$t_number, recgli$nt1d)
# Out:
#     recgli.b_number recgli.t_number recgli.nt1d
# 1   2723             6369             0.31
# 2   2312             5317             1.07
# 3   3169             7540            -0.08
# 4   2312             5317             1.25
# 5   2379             5950             0.52
# 6   2873             6709               NA
# 7   3118             7394             0.09
# 8   2873             6709               NA
# 9   3118             7394             0.04
# 10  2793             7584               NA
# 11  2222             6094             0.98
# 12  2873             6709               NA
# 13  2793             7584               NA
# 14  2118             6260             2.32
# 15  2723             6369            -0.10
# 16  2192             8070             0.94
# 17  2563             5983             0.08
# 18   963             6069               NA
# 19  2118             6260             0.95
# 20  2563             5983            -0.16
# 21   963             6069               NA
# ...

# %%
options(repr.matrix.max.rows=600, repr.matrix.max.cols=200)

# %% [markdown]
# #### In this notebook, we want to find: <br>
# 1. Anatomical params vs. TS using <br>
#     a. No separation into ROIs <br>
#     b. Visual comparison of anatomical params in separate regions <br>
#     ~~c. Repeated Measures ANOVA (analysis of variance) to account for multiple samples from the same patient to see if there is true separation among tumor scores for anatomical parameters~~ <b> you can't use RMANOVA for categorical data </b> (sources: http://sherifsoliman.com/2014/12/10/ANOVA_in_R/, https://www.r-bloggers.com/two-way-anova-with-repeated-measures/, https://www.r-statistics.com/tag/ezanova/) <br>
#     c. Use GLMM associate anatomical parameters with TS, no separation <br>
#     d. Use GEE to associate anatomical parameters with TS, no separation <br>
#     e. Use GLMM to associate anatomical parameters with TS, separating into CEL & NEL <br>
#     f. Use GEE to associate anatomical parameters with TS, separating into CEL & NEL <br>
#     g. Create histograms
#
# 2. Combining anat params vs. TS using GEE <br>
# 3. Using in_CEL as a covariate in anat params using GEE <br>
# 4. Using RM ANOVA to use imaging characteristics as the dependent variable, and the TS as independent variable

# %% [markdown]
# ## 0. Prep the data

# %%
colnames(recgli)
# Out:
#  [1] "b_number"                  "t_number"
#  [3] "sf_number"                 "current_scan_date"
#  [5] "current_surgery_date"      "current_hist_grade"
#  [7] "current_hist_type"         "roi.label"
#  [9] "tumor_cell_evaluation"     "necrosis"
# [11] "f8_delicate"               "f8_simple"
# [13] "f8_complex"                "mib_1"
# [15] "bx_pure_treatment_effect"  "nfse"
# [17] "nfl"                       "nt1c"
# [19] "nt1v"                      "nt1d"
# [21] "nadc.1"                    "nfa.1"
# [23] "nev1.1"                    "nev2.1"
# [25] "nev3.1"                    "nevrad.1"
# [27] "nadc.2"                    "nfa.2"
# [29] "nev1.2"                    "nev2.2"
# [31] "nev3.2"                    "nevrad.2"
# [33] "cbvn_nlin"                 "phn_nlin"
# [35] "phn_npar"                  "recovn_npar"
# [37] "cni"                       "ccri"
# [39] "crni"                      "ncho"
# [41] "ncre"                      "nnaa"
# [43] "laclip"                    "nlip"
# ...

# %% [markdown]
# The first thing we have to do is actually take away those that were "indeterminable" when tumor score was evaluated by the pathologist:

# %%
table(recgli$tumor_cell_evaluation)
# Out:
#   0   1   2   3 Ind
#  90  54 117 122   8

# %%
recgli = recgli[recgli$tumor_cell_evaluation != "Ind",]
dim(recgli)
recgli = droplevels(recgli)
recgli$tumor_cell_evaluation = as.character(recgli$tumor_cell_evaluation)
recgli$tumor_cell_evaluation = as.numeric(recgli$tumor_cell_evaluation)
str(recgli$tumor_cell_evaluation)
# Out:
# [1] 383  75
#  num [1:383] 0 2 2 2 0 1 0 2 1 0 ...

# %%
recgli.anat = recgli[recgli$include_anat==1,]
dim(recgli.anat)
# Out:
# [1] 383  75

# %%
recgli$t_number = as.factor(recgli$t_number)
#str(recgli)

# %%
summary(recgli$nt1d[recgli$olddata==1])
summary(recgli$nt1d[recgli$olddata==0])
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
# -0.3800  0.0300  0.3700  0.4872  0.8675  2.3200      86
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.     NA's
# -42.9300  -8.2125  -2.3200  -4.4525   0.4025  25.1200       23

# %% [markdown]
# ## 1. Anatomical vs. TS

# %% [markdown]
# ### a. No separation into ROIs

# %%
par(mfrow = c(2, 2))
a = boxplot(nfse ~ tumor_cell_evaluation , data = recgli, ylab = "normalized fse", xlab = "tumorscore", main = 'nfse vs. ts')
text( c(1:nlevels(factor(recgli$tumor_cell_evaluation))) , a$stats[nrow(a$stats) , ]+0.5 , paste("n = ",table(recgli$tumor_cell_evaluation),sep="")  )

b = boxplot(nfl ~ tumor_cell_evaluation , data = recgli, ylab = "normalized fl", xlab = "tumorscore", main = 'nfl vs. ts')
text( c(1:nlevels(factor(recgli$tumor_cell_evaluation))) , b$stats[nrow(b$stats) , ]+0.5 , paste("n = ",table(recgli$tumor_cell_evaluation),sep="")  )

c = boxplot(nt1c ~ tumor_cell_evaluation , data = recgli, ylab = "normalized t1c", xlab = "tumorscore", main = 'nt1c vs. ts')
text( c(1:nlevels(factor(recgli$tumor_cell_evaluation))) , c$stats[nrow(c$stats) , ]+0.5 , paste("n = ",table(recgli$tumor_cell_evaluation),sep="")  )

d = boxplot(nt1v ~ tumor_cell_evaluation , data = recgli, ylab = "normalized t1v", xlab = "tumorscore", main = 'nt1v vs. ts')
text( c(1:nlevels(factor(recgli$tumor_cell_evaluation))) , d$stats[nrow(d$stats) , ]+0.5 , paste("n = ",table(recgli$tumor_cell_evaluation),sep="")  )

e = boxplot(nt1d ~ tumor_cell_evaluation , data = recgli[recgli$olddata==1,], ylab = "normalized t1d", xlab = "tumorscore", main = 'nt1d vs. ts(olddata)')
text( c(1:nlevels(factor(recgli$tumor_cell_evaluation))) , e$stats[nrow(d$stats) , ]+0.5 , paste("n = ",table(recgli$tumor_cell_evaluation),sep="")  )

f = boxplot(nt1d ~ tumor_cell_evaluation , data = recgli[recgli$olddata==0,], ylab = "normalized t1d", xlab = "tumorscore", main = 'nt1d vs. ts (newdata)')
text( c(1:nlevels(factor(recgli$tumor_cell_evaluation))) , e$stats[nrow(d$stats) , ]+0.5 , paste("n = ",table(recgli$tumor_cell_evaluation),sep="")  )
# Out:
# Plot with title “nt1v vs. ts”
# Plot with title “nt1d vs. ts (newdata)”

# %% [markdown]
# ### b. CEL next to NEL scores

# %%
par(mfrow = c(2, 2))
a = boxplot(nfse ~ tumor_cell_evaluation , data = recgli[recgli$in_CEL ==1,], ylab = "normalized fse", xlab = "tumorscore", main = "CEL", ylim = c(0,4))
text( c(1:nlevels(factor(recgli$tumor_cell_evaluation))) , a$stats[nrow(a$stats) , ]+.3 , paste("n = ",table(recgli[which(recgli$in_CEL ==1),]$tumor_cell_evaluation),sep=""), cex = 0.8)

b = boxplot(nfse ~ tumor_cell_evaluation , data = recgli[recgli$in_NEL ==1,], ylab = "normalized fse", xlab = "tumorscore", main = "NEL", ylim = c(0,4))
text( c(1:nlevels(factor(recgli$tumor_cell_evaluation))) , b$stats[nrow(b$stats) , ]+.3 , paste("n = ",table(recgli[which(recgli$in_NEL ==1),]$tumor_cell_evaluation),sep=""), cex = 0.8)

c = boxplot(nfl ~ tumor_cell_evaluation , data = recgli[recgli$in_CEL ==1,], ylab = "normalized fl", xlab = "tumorscore", main = "CEL", ylim = c(0,3.5))
text( c(1:nlevels(factor(recgli$tumor_cell_evaluation))) , c$stats[nrow(c$stats) , ]+.3 , paste("n = ",table(recgli[which(recgli$in_CEL ==1),]$tumor_cell_evaluation),sep=""), cex = 0.8)
d = boxplot(nfl ~ tumor_cell_evaluation , data = recgli[recgli$in_NEL ==1,], ylab = "normalized fl", xlab = "tumorscore", main = "NEL", ylim = c(0,3.5))
text( c(1:nlevels(factor(recgli$tumor_cell_evaluation))) , d$stats[nrow(d$stats) , ]+.3 , paste("n = ",table(recgli[which(recgli$in_NEL ==1),]$tumor_cell_evaluation),sep=""), cex = 0.8)

e = boxplot(nt1c ~ tumor_cell_evaluation , data = recgli[recgli$in_CEL ==1,], ylab = "normalized t1c", xlab = "tumorscore", main = "CEL", ylim = c(0,4))
text( c(1:nlevels(factor(recgli$tumor_cell_evaluation))) , e$stats[nrow(e$stats) , ]+.3 , paste("n = ",table(recgli[recgli$in_CEL ==1,]$tumor_cell_evaluation),sep=""), cex = 0.8)
f = boxplot(nt1c ~ tumor_cell_evaluation , data = recgli[recgli$in_NEL ==1,], ylab = "normalized t1c", xlab = "tumorscore", main = "NEL", ylim = c(0,4))
text( c(1:nlevels(factor(recgli$tumor_cell_evaluation))) , f$stats[nrow(f$stats) , ]+.3 , paste("n = ",table(recgli[recgli$in_NEL ==1,]$tumor_cell_evaluation),sep=""), cex = 0.8)

g = boxplot(nt1v ~ tumor_cell_evaluation , data = recgli[recgli$in_CEL ==1,], ylab = "normalized t1v", xlab = "tumorscore", main = "CEL", ylim = c(0,4))
text( c(1:nlevels(factor(recgli$tumor_cell_evaluation))) , g$stats[nrow(g$stats) , ]+.3 , paste("n = ",table(recgli[recgli$in_CEL ==1,]$tumor_cell_evaluation),sep=""), cex = 0.8)
h = boxplot(nt1v ~ tumor_cell_evaluation , data = recgli[recgli$in_NEL ==1,], ylab = "normalized t1v", xlab = "tumorscore", main = "NEL", ylim = c(0,4))
text( c(1:nlevels(factor(recgli$tumor_cell_evaluation))) , h$stats[nrow(h$stats) , ]+.3 , paste("n = ",table(recgli[recgli$in_NEL ==1,]$tumor_cell_evaluation),sep=""), cex = 0.8)

i = boxplot(nt1d ~ tumor_cell_evaluation , data = recgli[recgli$in_CEL ==1 & recgli$olddata==1,], ylab = "normalized t1d (olddata)", xlab = "tumorscore", main = "CEL", ylim = c(0,4))
text( c(1:nlevels(factor(recgli$tumor_cell_evaluation))) , i$stats[nrow(i$stats) , ]+.3 , paste("n = ",table(recgli[recgli$in_CEL ==1,]$tumor_cell_evaluation),sep=""), cex = 0.8)
j = boxplot(nt1d ~ tumor_cell_evaluation , data = recgli[recgli$in_NEL ==1 & recgli$olddata==1,], ylab = "normalized t1d (olddata)", xlab = "tumorscore", main = "NEL", ylim = c(0,4))
text( c(1:nlevels(factor(recgli$tumor_cell_evaluation))) , j$stats[nrow(j$stats) , ]+.3 , paste("n = ",table(recgli[recgli$in_NEL ==1,]$tumor_cell_evaluation),sep=""), cex = 0.8)

i = boxplot(nt1d ~ tumor_cell_evaluation , data = recgli[recgli$in_CEL ==1 & recgli$olddata==0,], ylab = "normalized t1d (newdata)", xlab = "tumorscore", main = "CEL", ylim = c(-30,10))
text( c(1:nlevels(factor(recgli$tumor_cell_evaluation))) , i$stats[nrow(i$stats) , ]+.3 , paste("n = ",table(recgli[recgli$in_CEL ==1,]$tumor_cell_evaluation),sep=""), cex = 0.8)
j = boxplot(nt1d ~ tumor_cell_evaluation , data = recgli[recgli$in_NEL ==1 & recgli$olddata==0,], ylab = "normalized t1d (newdata)", xlab = "tumorscore", main = "NEL", ylim = c(-30,10))
text( c(1:nlevels(factor(recgli$tumor_cell_evaluation))) , j$stats[nrow(j$stats) , ]+.3 , paste("n = ",table(recgli[recgli$in_NEL ==1,]$tumor_cell_evaluation),sep=""), cex = 0.8)
# Out:
# Plot with title “NEL”
# Plot with title “NEL”
# Plot with title “NEL”

# %% [markdown]
# There is no package with a straightforward implementation of a multinomial logistic regression with mixed effects in R. Packages w/ mixed effects modeling for logistic regression include lme4, glmm; Packages w/ multinomial log reg include mlogit.

# %% [markdown]
# ### c. Use GLMM associate anatomical parameters with TS, no separation

# %%
#install.packages('mlogit')

# %%
library(mlogit)

# %%
data.frame(index = 1:length(colnames(recgli)), colnames = colnames(recgli))
# Out:
#    index colnames
# 1   1    b_number
# 2   2    t_number
# 3   3    sf_number
# 4   4    current_scan_date
# 5   5    current_surgery_date
# 6   6    current_hist_grade
# 7   7    current_hist_type
# 8   8    roi.label
# 9   9    tumor_cell_evaluation
# 10 10    necrosis
# 11 11    f8_delicate
# 12 12    f8_simple
# 13 13    f8_complex
# 14 14    mib_1
# 15 15    bx_pure_treatment_effect
# 16 16    nfse
# 17 17    nfl
# 18 18    nt1c
# 19 19    nt1v
# 20 20    nt1d
# 21 21    nadc.1
# 22 22    nfa.1
# 23 23    nev1.1
# 24 24    nev2.1
# 25 25    nev3.1
# 26 26    nevrad.1
# 27 27    nadc.2
# 28 28    nfa.2
# 29 29    nev1.2
# 30 30    nev2.2
# 31 31    nev3.2
# 32 32    nevrad.2
# 33 33    cbvn_nlin
# 34 34    phn_nlin
# 35 35    phn_npar
# 36 36    recovn_npar
# 37 37    cni
# 38 38    ccri
# 39 39    crni
# 40 40    ncho
# 41 41    ncre
# 42 42    nnaa
# 43 43    laclip
# 44 44    nlip
# 45 45    nlac
# 46 46    olddata
# 47 47    newdata
# 48 48    comments
# 49 49    notes.
# ...

# %%
str(recgli$tumor_cell_evaluation)
recgli$tumor_cell_evaluation = as.factor(recgli$tumor_cell_evaluation)
# Out:
#  num [1:383] 0 2 2 2 0 1 0 2 1 0 ...

# %%
data_mlog <-mlogit.data(recgli,  id.var ="t_number", shape="wide", 
                        sep="", varying=NULL, 
                       choice = "tumor_cell_evaluation")

# %%
mlogit_nfse <- mlogit(tumor_cell_evaluation ~1 | nfse, data=data_mlog)

# %%
summary(mlogit_nfse)$CoefTable
# Out:
#               Estimate   Std. Error z-value    Pr(>|z|)
# 1:(intercept) -0.2079333 0.4557915  -0.4562028 0.64824417
# 2:(intercept)  0.8040000 0.3836778   2.0955083 0.03612583
# 3:(intercept)  0.6836297 0.3684711   1.8553144 0.06355134
# 1:nfse        -0.1518534 0.2135148  -0.7112078 0.47695550
# 2:nfse        -0.2768463 0.1827241  -1.5151054 0.12974572
# 3:nfse        -0.1914444 0.1720886  -1.1124754 0.26593380

# %%
## univariate analysis: 
mlogit_nfl <- mlogit(tumor_cell_evaluation ~1 | nfl, data=data_mlog)
summary(mlogit_nfl)$CoefTable
# Out:
#               Estimate   Std. Error z-value     Pr(>|z|)
# 1:(intercept) -0.3325272 0.5939910  -0.55981857 0.5756032
# 2:(intercept) -0.4421119 0.5026628  -0.87953962 0.3791088
# 3:(intercept)  0.3376085 0.4815920   0.70102598 0.4832868
# 1:nfl         -0.1213727 0.3509173  -0.34587278 0.7294383
# 2:nfl          0.4073119 0.2869562   1.41942154 0.1557762
# 3:nfl         -0.0204239 0.2819278  -0.07244372 0.9422488

# %%
mlogit_nt1c <- mlogit(tumor_cell_evaluation ~1 | nt1c, data=data_mlog)
summary(mlogit_nt1c)$CoefTable
# Out:
#               Estimate    Std. Error z-value    Pr(>|z|)
# 1:(intercept) -0.38701522 0.4320916  -0.8956787 0.37042441
# 2:(intercept)  0.59018325 0.3533462   1.6702693 0.09486609
# 3:(intercept)  0.16019503 0.3479718   0.4603678 0.64525226
# 1:nt1c        -0.09604602 0.3084020  -0.3114312 0.75547282
# 2:nt1c        -0.25927691 0.2557460  -1.0138065 0.31067511
# 3:nt1c         0.10892745 0.2418360   0.4504186 0.65240860

# %%
mlogit_nt1v <- mlogit(tumor_cell_evaluation ~1 | nt1v, data=data_mlog)
summary(mlogit_nt1v)$CoefTable
exp(coefficients(mlogit_nt1v))
# Out:
#               Estimate   Std. Error z-value    Pr(>|z|)
# 1:(intercept)  0.3630492 0.7951476   0.4565809 0.647972308
# 2:(intercept)  1.7931983 0.6852660   2.6167915 0.008876055
# 3:(intercept)  1.4100270 0.6303412   2.2369266 0.025291139
# 1:nt1v        -1.0479162 0.9075827  -1.1546234 0.248244690
# 2:nt1v        -1.9756226 0.7957088  -2.4828463 0.013033730
# 3:nt1v        -1.2318767 0.7144343  -1.7242687 0.084659356
# 1:(intercept) 2:(intercept) 3:(intercept)        1:nt1v        2:nt1v
#     1.4377066     6.0086389     4.0960660     0.3506677     0.1386749
#        3:nt1v
#     0.2917445

# %%
data_mlog_old <-mlogit.data(recgli[recgli$olddata==1,],  id.var ="t_number", shape="wide", 
                        sep="", varying=NULL, 
                       choice = "tumor_cell_evaluation")

# %%
mlogit_nt1d_old <- mlogit(tumor_cell_evaluation ~1 | nt1d, data=data_mlog_old)
summary(mlogit_nt1d_old)$CoefTable
exp(coefficients(mlogit_nt1d_old))
# Out:
#               Estimate   Std. Error z-value    Pr(>|z|)
# 1:(intercept) -1.0124398 0.3515736  -2.8797380 0.003980058
# 2:(intercept) -1.1372605 0.3580998  -3.1758205 0.001494134
# 3:(intercept) -1.0961262 0.3445913  -3.1809460 0.001467950
# 1:nt1d         0.1494176 0.6015366   0.2483933 0.803830147
# 2:nt1d         0.8663910 0.5226220   1.6577776 0.097362371
# 3:nt1d         1.4408317 0.4712051   3.0577589 0.002229989
# 1:(intercept) 2:(intercept) 3:(intercept)        1:nt1d        2:nt1d
#     0.3633315     0.3206964     0.3341630     1.1611578     2.3783121
#        3:nt1d
#     4.2242077

# %%
data_mlog_new <-mlogit.data(recgli[recgli$olddata==0,],  id.var ="t_number", shape="wide", 
                        sep="", varying=NULL, 
                       choice = "tumor_cell_evaluation")

# %%
mlogit_nt1d_new <- mlogit(tumor_cell_evaluation ~1 | nt1d, data=data_mlog_new)
summary(mlogit_nt1d_new)$CoefTable
exp(coefficients(mlogit_nt1d_new))
# Out:
#               Estimate   Std. Error z-value   Pr(>|z|)
# 1:(intercept) 0.08791153 0.34448334 0.2551982 7.985700e-01
# 2:(intercept) 0.72970398 0.30314115 2.4071426 1.607789e-02
# 3:(intercept) 1.14722396 0.28623694 4.0079522 6.124752e-05
# 1:nt1d        0.04168632 0.03876140 1.0754596 2.821690e-01
# 2:nt1d        0.01111053 0.02999746 0.3703825 7.110975e-01
# 3:nt1d        0.02212500 0.02892996 0.7647782 4.444036e-01
# 1:(intercept) 2:(intercept) 3:(intercept)        1:nt1d        2:nt1d
#      1.091892      2.074466      3.149438      1.042567      1.011172
#        3:nt1d
#      1.022372

# %% [markdown]
# ### d. Use GEE to associate anatomical parameters with TS, no separation

# %%
library(glmnet)
library(geepack)
library(lme4)
#install.packages("multgee")
library("multgee")
# Out:
# Loading required package: Matrix
# Loading required package: foreach
# Loaded glmnet 2.0-16
#
# Loading required package: gnm
# Loading required package: VGAM
# Loading required package: stats4
# Loading required package: splines
#
# Attaching package: ‘VGAM’
#
# The following object is masked from ‘package:mlogit’:
#
#     lrtest

# %%
#nfse.fit = geeglm(tumor_cell_evaluation ~ nfse, data = recgli, id = t_number, corstr = "exchangeable")
#anova(nfse.fit)

nfse.fit = ordLORgee(formula = tumor_cell_evaluation ~ nfse, link = "logit", 
                      id = t_number, data = recgli, LORstr = "category.exch")
summary(nfse.fit)$coefficients
# Out:
# Warning message in eval(slot(family, "initialize")):
# “response should be ordinal---see ordered()”
#        Estimate san.se  san.z    Pr(>|san.z|)
# beta10 -1.20100 0.28409 -4.22755 0.00002
# beta20 -0.54916 0.27312 -2.01068 0.04436
# beta30  0.73916 0.26321  2.80830 0.00498
# nfse    0.00249 0.13007  0.01913 0.98474

# %%
nfl.fit = ordLORgee(formula = tumor_cell_evaluation ~ nfl, link = "logit", 
                      id = t_number, data = recgli, LORstr = "category.exch")
summary(nfl.fit)$coefficients
# Out:
# Warning message in eval(slot(family, "initialize")):
# “response should be ordinal---see ordered()”
#        Estimate san.se  san.z    Pr(>|san.z|)
# beta10 -1.07602 0.28743 -3.74359 0.00018
# beta20 -0.43267 0.28023 -1.54398 0.12259
# beta30  0.86553 0.27351  3.16449 0.00155
# nfl    -0.07777 0.14118 -0.55088 0.58172

# %%
nt1c.fit = ordLORgee(formula = tumor_cell_evaluation ~ nt1c, link = "logit", 
                      id = t_number, data = recgli, LORstr = "category.exch")
summary(nt1c.fit)$coefficients
# Out:
# Warning message in eval(slot(family, "initialize")):
# “response should be ordinal---see ordered()”
#        Estimate san.se  san.z    Pr(>|san.z|)
# beta10 -1.33106 0.24358 -5.46465 0.00000
# beta20 -0.69825 0.23436 -2.97940 0.00289
# beta30  0.57859 0.23207  2.49316 0.01266
# nt1c    0.12447 0.14702  0.84665 0.39719

# %%
nt1v.fit = ordLORgee(formula = tumor_cell_evaluation ~ nt1v, link = "logit", 
                      id = t_number, data = recgli, LORstr = "category.exch")
summary(nt1v.fit)$coefficients
# Out:
# Warning message in eval(slot(family, "initialize")):
# “response should be ordinal---see ordered()”
#        Estimate san.se  san.z    Pr(>|san.z|)
# beta10 -2.12226 0.54778 -3.87426 0.00011
# beta20 -1.44389 0.52556 -2.74735 0.00601
# beta30 -0.28343 0.50955 -0.55624 0.57804
# nt1v    1.15949 0.62223  1.86345 0.06240

# %%
nt1d.fit = ordLORgee(formula = tumor_cell_evaluation ~ nt1d, link = "logit", 
                      id = t_number, data = recgli, LORstr = "category.exch")
summary(nt1d.fit)$coefficients
# Out:
# Warning message in eval(slot(family, "initialize")):
# “response should be ordinal---see ordered()”
#        Estimate san.se  san.z    Pr(>|san.z|)
# beta10 -1.14307 0.20640 -5.53802 0.00000
# beta20 -0.48158 0.18359 -2.62309 0.00871
# beta30  0.52492 0.16533  3.17489 0.00150
# nt1d   -0.01949 0.01548 -1.25883 0.20809

# %% [markdown]
# ### e. Use GLMM to associate anatomical parameters with TS, separating into CEL & NEL

# %%
## need to come back to when becomes more obvious how to do GLMM with multinomial outcome... 
##can do this using a one-v-all method

# %% [markdown]
# ### f. Use GEE to associate anatomical parameters with TS, separating into CEL & NEL

# %%
recgli_inCEL = recgli[which(recgli$in_CEL == 1),]
dim(recgli_inCEL)
is.numeric(recgli_inCEL$tumor_cell_evaluation)
head(recgli_inCEL)
# Out:
# [1] 179  75
# [1] FALSE
#    b_number t_number sf_number current_scan_date current_surgery_date
# 1  2723     6369     8122      9/13/09           9/14/09
# 2  2312     5317     7679      5/4/08            5/4/08
# 4  2312     5317     7679      5/4/08            5/4/08
# 6  2873     6709     8269      3/11/10           3/15/10
# 9  3118     7394     8688      3/15/11           3/16/11
# 11 2222     6094     7758      8/3/08            8/4/08
#    current_hist_grade current_hist_type roi.label tumor_cell_evaluation
# 1  Grade IV           Glioblastoma      10B28     0
# 2  Grade IV           Glioblastoma      11B16     2
# 4  Grade IV           Glioblastoma      12B16     2
# 6  Grade IV           Glioblastoma      13B32     1
# 9  Treatment Effect   Treatment Effect  14B41     1
# 11 Grade IV           Glioblastoma      15B18     0
#    necrosis f8_delicate f8_simple f8_complex mib_1 bx_pure_treatment_effect
# 1  0        2           1         0           0.82 t
# ...

# %%
coef_init = summary(nfse.fit)$coefficients[,1]

# %%
nfse.fit2 = ordLORgee(formula = tumor_cell_evaluation ~ nfse, link = "logit", 
                      id = t_number, data = recgli_inCEL, LORstr = "category.exch", 
                    bstart = coef_init)
## for some reason this throws an error, I reported to the github and hope that there is a resolution of this issue
# Out:
# Error in fitLORgee(Y, X_mat, coeffs, ncategories, id, repeated, offset, : Please insert initial values
# Traceback:
#
# 1. ordLORgee(formula = tumor_cell_evaluation ~ nfse, link = "logit",
#  .     id = t_number, data = recgli_inCEL, LORstr = "category.exch",
#  .     bstart = coef_init)
# 2. fitLORgee(Y, X_mat, coeffs, ncategories, id, repeated, offset,
#  .     link, LORterm, marpars, ipfp.ctrl, control, IM, LORem = LORem,
#  .     LORstr = LORstr, add)
# 3. stop("Please insert initial values")

# %%
head(recgli)
# Out:
#   b_number t_number sf_number current_scan_date current_surgery_date
# 1 2723     6369     8122      9/13/09           9/14/09
# 2 2312     5317     7679      5/4/08            5/4/08
# 3 3169     7540     8796      6/19/11           6/20/11
# 4 2312     5317     7679      5/4/08            5/4/08
# 5 2379     5950     7930      1/25/09           1/26/09
# 6 2873     6709     8269      3/11/10           3/15/10
#   current_hist_grade current_hist_type roi.label tumor_cell_evaluation necrosis
# 1 Grade IV           Glioblastoma      10B28     0                     0
# 2 Grade IV           Glioblastoma      11B16     2                     1
# 3 Grade IV           Glioblastoma      11B43     2                     0
# 4 Grade IV           Glioblastoma      12B16     2                     1
# 5 Treatment Effect   Treatment Effect  12B22     0                     0
# 6 Grade IV           Glioblastoma      13B32     1                     0
# ...

# %% [markdown]
# ### g. create histograms to describe anat params:

# %%
par(mfrow=c(2,2))
hist(recgli[which(recgli$in_CEL==1),]$nfse, breaks=35, ylim = c(0, 20),  xlim=c(0,5), col=rgb(1,0,0,0.5), xlab="nfse value", 
     ylab="", main="distribution of nfse\n values in CEL vs in NEL")
hist(recgli[which(recgli$in_NEL==1),]$nfse, breaks=35, ylim = c(0, 20),  xlim=c(0,5), col=rgb(0,0,1,0.5), add=T)
legend("topright", legend=c("in CEL","in NEL"), col=c(rgb(1,0,0,0.5), 
     rgb(0,0,1,0.5)), pt.cex=2, pch=15, cex = .8 )

hist(recgli[which(recgli$in_CEL==1),]$nfl, breaks=35, ylim = c(0, 20),  xlim=c(0,4), col=rgb(1,0,0,0.5), xlab="nfl value", 
     ylab="", main="distribution of nfl\n values in CEL vs in NEL")
hist(recgli[which(recgli$in_NEL==1),]$nfl, breaks=35, ylim = c(0, 20),  xlim=c(0,4), col=rgb(0,0,1,0.5), add=T)
legend("topright", legend=c("in CEL","in NEL"), col=c(rgb(1,0,0,0.5), 
     rgb(0,0,1,0.5)), pt.cex=2, pch=15, cex = .8 )

hist(recgli[which(recgli$in_CEL==1),]$nt1c, breaks=35, ylim = c(0, 20),  xlim=c(0,4), col=rgb(1,0,0,0.5), xlab="nt1c value", 
     ylab="", main="distribution of nt1c\n values in CEL vs in NEL")
hist(recgli[which(recgli$in_NEL==1),]$nt1c, breaks=35, ylim = c(0, 20),  xlim=c(0,4), col=rgb(0,0,1,0.5), add=T)
legend("topright", legend=c("in CEL","in NEL"), col=c(rgb(1,0,0,0.5), 
     rgb(0,0,1,0.5)), pt.cex=2, pch=15, cex = .8 )

hist(recgli[which(recgli$in_CEL==1),]$nt1v, breaks=35, ylim = c(0, 20),  xlim=c(0,3), col=rgb(1,0,0,0.5), xlab="nt1v value", 
     ylab="", main="distribution of nt1v\n values in CEL vs in NEL")
hist(recgli[which(recgli$in_NEL==1),]$nt1v, breaks=35, ylim = c(0, 20),  xlim=c(0,3), col=rgb(0,0,1,0.5), add=T)
legend("topright", legend=c("in CEL","in NEL"), col=c(rgb(1,0,0,0.5), 
     rgb(0,0,1,0.5)), pt.cex=2, pch=15, cex = .8 )

hist(recgli[which(recgli$in_CEL==1),]$nt1d, breaks=35, ylim = c(0, 40),  xlim=c(0,3), col=rgb(1,0,0,0.5), xlab="nt1d value", 
     ylab="", main="distribution of nt1d\n values in CEL vs in NEL")
hist(recgli[which(recgli$in_NEL==1),]$nt1d, breaks=35, ylim = c(0, 40),  xlim=c(0,3), col=rgb(0,0,1,0.5), add=T)
legend("topright", legend=c("in CEL","in NEL"), col=c(rgb(1,0,0,0.5), 
     rgb(0,0,1,0.5)), pt.cex=2, pch=15, cex = .8 )
# Out:
# Plot with title “distribution of nt1v
#  values in CEL vs in NEL”
# Plot with title “distribution of nt1d
#  values in CEL vs in NEL”

# %%
par(mfrow=c(1,1))

hist(recgli[which(recgli$tumor_cell_evaluation==0 ),]$nfse, breaks=35, ylim = c(0, 10),  xlim=c(-1,3), col=rgb(1,0,0,0.5), xlab="nfse value", 
     ylab="", main="distribution of nfse\n in TS")
hist(recgli[which(recgli$tumor_cell_evaluation==1 ),]$nfse, breaks=35, ylim = c(0, 10),  xlim=c(-1,3), col=rgb(0,1,0,0.5), add=T)
hist(recgli[which(recgli$tumor_cell_evaluation==2 ),]$nfse, breaks=35, ylim = c(0, 10),  xlim=c(-1,3), col=rgb(0,0,1,0.5), add=T)
hist(recgli[which(recgli$tumor_cell_evaluation==3 ),]$nfse, breaks=35, ylim = c(0, 10),  xlim=c(-1,3), col=rgb(0,1,1,0.5), add=T)
legend("topright", legend=c("0","1", "2", "3"), col=c(rgb(1,0,0,0.5), 
     rgb(0,1,0,0.5), rgb(0,0,1,0.5), rgb(0,1,1,0.5)), pt.cex=2, pch=15, cex = .7 )

# %%
par(mfrow=c(1,1))

hist(recgli[which(recgli$tumor_cell_evaluation==0 ),]$nt1c, breaks=35, ylim = c(0, 10),  xlim=c(-1,3), col=rgb(1,0,0,0.5), xlab="nt1c value", 
     ylab="", main="distribution of nt1c\n in TS")
hist(recgli[which(recgli$tumor_cell_evaluation==1 ),]$nt1c, breaks=35, ylim = c(0, 10),  xlim=c(-1,3), col=rgb(0,1,0,0.5), add=T)
hist(recgli[which(recgli$tumor_cell_evaluation==2 ),]$nt1c, breaks=35, ylim = c(0, 10),  xlim=c(-1,3), col=rgb(0,0,1,0.5), add=T)
hist(recgli[which(recgli$tumor_cell_evaluation==3 ),]$nt1c, breaks=35, ylim = c(0, 10),  xlim=c(-1,3), col=rgb(0,1,1,0.5), add=T)
legend("topright", legend=c("0","1", "2", "3"), col=c(rgb(1,0,0,0.5), 
     rgb(0,1,0,0.5), rgb(0,0,1,0.5), rgb(0,1,1,0.5)), pt.cex=2, pch=15, cex = .7 )

# %%
par(mfrow=c(1,1))

hist(recgli[which(recgli$tumor_cell_evaluation==0 ),]$nt1c, breaks=35, ylim = c(0, 10),  xlim=c(-1,3), col=rgb(1,0,0,0.5), xlab="nt1c value", 
     ylab="", main="distribution of nt1c\n in TS")
hist(recgli[which(recgli$tumor_cell_evaluation==1 ),]$nt1c, breaks=35, ylim = c(0, 10),  xlim=c(-1,3), col=rgb(0,1,0,0.5), add=T)
hist(recgli[which(recgli$tumor_cell_evaluation==2 ),]$nt1c, breaks=35, ylim = c(0, 10),  xlim=c(-1,3), col=rgb(0,0,1,0.5), add=T)
hist(recgli[which(recgli$tumor_cell_evaluation==3 ),]$nt1c, breaks=35, ylim = c(0, 10),  xlim=c(-1,3), col=rgb(0,1,1,0.5), add=T)
legend("topright", legend=c("0","1", "2", "3"), col=c(rgb(1,0,0,0.5), 
     rgb(0,1,0,0.5), rgb(0,0,1,0.5), rgb(0,1,1,0.5)), pt.cex=2, pch=15, cex = .7 )
# Out:
# Plot with title “distribution of nt1c
#  in TS”

# %%
par(mfrow=c(1,1))

hist(recgli[which(recgli$tumor_cell_evaluation==0 & recgli$olddata==1),]$nt1d, breaks=35, ylim = c(0, 10),  xlim=c(-1,3), col=rgb(1,0,0,0.5), xlab="nt1d value", 
     ylab="", main="distribution of nt1d\n in TS")
hist(recgli[which(recgli$tumor_cell_evaluation==1 & recgli$olddata==1),]$nt1d, breaks=35, ylim = c(0, 10),  xlim=c(-1,3), col=rgb(0,1,0,0.5), add=T)
hist(recgli[which(recgli$tumor_cell_evaluation==2 & recgli$olddata==1),]$nt1d, breaks=35, ylim = c(0, 10),  xlim=c(-1,3), col=rgb(0,0,1,0.5), add=T)
hist(recgli[which(recgli$tumor_cell_evaluation==3 & recgli$olddata==1),]$nt1d, breaks=35, ylim = c(0, 10),  xlim=c(-1,3), col=rgb(0,1,1,0.5), add=T)
legend("topright", legend=c("0","1", "2", "3"), col=c(rgb(1,0,0,0.5), 
     rgb(0,1,0,0.5), rgb(0,0,1,0.5), rgb(0,1,1,0.5)), pt.cex=2, pch=15, cex = .7 )
# Out:
# Plot with title “distribution of nt1d
#  in TS”

# %%
head(recgli[which(!is.na(recgli$nt1d) & recgli$olddata ==1),])

head(recgli[which(!is.na(recgli$nt1d) & recgli$olddata ==1),])


range(recgli$nt1d[which(!is.na(recgli$nt1d) & recgli$olddata ==1)])
range(recgli$nt1d[which(!is.na(recgli$nt1d) & recgli$newdata ==1)])
# Out:
#   b_number t_number sf_number current_scan_date current_surgery_date
# 1 2723     6369     8122      9/13/09           9/14/09
# 2 2312     5317     7679      5/4/08            5/4/08
# 3 3169     7540     8796      6/19/11           6/20/11
# 4 2312     5317     7679      5/4/08            5/4/08
# 5 2379     5950     7930      1/25/09           1/26/09
# 7 3118     7394     8688      3/15/11           3/16/11
#   current_hist_grade current_hist_type roi.label tumor_cell_evaluation necrosis
# 1 Grade IV           Glioblastoma      10B28     0                     0
# 2 Grade IV           Glioblastoma      11B16     2                     1
# 3 Grade IV           Glioblastoma      11B43     2                     0
# 4 Grade IV           Glioblastoma      12B16     2                     1
# 5 Treatment Effect   Treatment Effect  12B22     0                     0
# 7 Treatment Effect   Treatment Effect  13B41     0                     0
# ...

# %%
par(mfrow=c(2,2))
#------------ NFSE CEL
hist(recgli[which(recgli$in_CEL==1 & recgli$multnom_out=="TxE"),]$nfse, breaks=35, ylim = c(0, 20),  xlim=c(0,5), col=rgb(1,0,0,0.5), xlab="nfse value", 
     ylab="", main="distribution of nfse\n values in CEL vs in NEL")
hist(recgli[which(recgli$in_CEL==1 & recgli$multnom_out=="rHGG"),]$nfse, breaks=35, ylim = c(0, 20),  xlim=c(0,5), col=rgb(0,0,1,0.5), add=T)
legend("topright", legend=c("in CEL & TxE","in CEL & rHGG"), col=c(rgb(1,0,0,0.5), 
     rgb(0,0,1,0.5)), pt.cex=2, pch=15, cex = .8 )
#------------ NFSE NEL
hist(recgli[which(recgli$in_NEL==1 & recgli$multnom_out=="TxE"),]$nfse, breaks=35, ylim = c(0, 20),  xlim=c(0,5), col=rgb(1,0,0,0.5), xlab="nfse value", 
     ylab="", main="distribution of nfse\n values in CEL vs in NEL")
hist(recgli[which(recgli$in_NEL==1 & recgli$multnom_out=="rHGG"),]$nfse, breaks=35, ylim = c(0, 20),  xlim=c(0,5), col=rgb(0,0,1,0.5), add=T)
legend("topright", legend=c("in NEL & TxE","in NEL & rHGG"), col=c(rgb(1,0,0,0.5), 
     rgb(0,0,1,0.5)), pt.cex=2, pch=15, cex = .8 )
#------------ NFL CEL
hist(recgli[which(recgli$in_CEL==1 & recgli$multnom_out=="TxE"),]$nfl, breaks=35, ylim = c(0, 20),  xlim=c(0,5), col=rgb(1,0,0,0.5), xlab="nfl value", 
     ylab="", main="distribution of nfl\n values in CEL vs in NEL")
hist(recgli[which(recgli$in_CEL==1 & recgli$multnom_out=="rHGG"),]$nfl, breaks=35, ylim = c(0, 20),  xlim=c(0,5), col=rgb(0,0,1,0.5), add=T)
legend("topright", legend=c("in CEL & TxE","in CEL & rHGG"), col=c(rgb(1,0,0,0.5), 
     rgb(0,0,1,0.5)), pt.cex=2, pch=15, cex = .8 )
#------------ NFL NEL
hist(recgli[which(recgli$in_NEL==1 & recgli$multnom_out=="TxE"),]$nfl, breaks=35, ylim = c(0, 20),  xlim=c(0,5), col=rgb(1,0,0,0.5), xlab="nfl value", 
     ylab="", main="distribution of nfl\n values in CEL vs in NEL")
hist(recgli[which(recgli$in_NEL==1 & recgli$multnom_out=="rHGG"),]$nfl, breaks=35, ylim = c(0, 20),  xlim=c(0,5), col=rgb(0,0,1,0.5), add=T)
legend("topright", legend=c("in NEL & TxE","in NEL & rHGG"), col=c(rgb(1,0,0,0.5), 
     rgb(0,0,1,0.5)), pt.cex=2, pch=15, cex = .8 )

    #------------ NT1C CEL
par(mfrow=c(2,2))
hist(recgli[which(recgli$in_CEL==1 & recgli$multnom_out=="TxE"),]$nt1c, breaks=35, ylim = c(0, 20),  xlim=c(0,5), col=rgb(1,0,0,0.5), xlab="nt1c value", 
     ylab="", main="distribution of nt1c\n values in CEL vs in NEL")
hist(recgli[which(recgli$in_CEL==1 & recgli$multnom_out=="rHGG"),]$nt1c, breaks=35, ylim = c(0, 20),  xlim=c(0,5), col=rgb(0,0,1,0.5), add=T)
legend("topright", legend=c("in CEL & TxE","in CEL & rHGG"), col=c(rgb(1,0,0,0.5), 
     rgb(0,0,1,0.5)), pt.cex=2, pch=15, cex = .8 )
#------------ NT1C NEL
hist(recgli[which(recgli$in_NEL==1 & recgli$multnom_out=="TxE"),]$nt1c, breaks=35, ylim = c(0, 20),  xlim=c(0,5), col=rgb(1,0,0,0.5), xlab="nt1c value", 
     ylab="", main="distribution of nt1c\n values in CEL vs in NEL")
hist(recgli[which(recgli$in_NEL==1 & recgli$multnom_out=="rHGG"),]$nt1c, breaks=35, ylim = c(0, 20),  xlim=c(0,5), col=rgb(0,0,1,0.5), add=T)
legend("topright", legend=c("in NEL & TxE","in NEL & rHGG"), col=c(rgb(1,0,0,0.5), 
     rgb(0,0,1,0.5)), pt.cex=2, pch=15, cex = .8 )
#------------ NT1V CEL

hist(recgli[which(recgli$in_CEL==1 & recgli$multnom_out=="TxE"),]$nt1v, breaks=35, ylim = c(0, 20),  xlim=c(0,5), col=rgb(1,0,0,0.5), xlab="nt1v value", 
     ylab="", main="distribution of nt1v\n values in CEL vs in NEL")
hist(recgli[which(recgli$in_CEL==1 & recgli$multnom_out=="rHGG"),]$nt1v, breaks=35, ylim = c(0, 20),  xlim=c(0,5), col=rgb(0,0,1,0.5), add=T)
legend("topright", legend=c("in CEL & TxE","in CEL & rHGG"), col=c(rgb(1,0,0,0.5), 
     rgb(0,0,1,0.5)), pt.cex=2, pch=15, cex = .8 )
#------------ NT1V NEL
hist(recgli[which(recgli$in_NEL==1 & recgli$multnom_out=="TxE"),]$nt1v, breaks=35, ylim = c(0, 20),  xlim=c(0,5), col=rgb(1,0,0,0.5), xlab="nt1v value", 
     ylab="", main="distribution of nt1v\n values in CEL vs in NEL")
hist(recgli[which(recgli$in_NEL==1 & recgli$multnom_out=="rHGG"),]$nt1v, breaks=35, ylim = c(0, 20),  xlim=c(0,5), col=rgb(0,0,1,0.5), add=T)
legend("topright", legend=c("in NEL & TxE","in NEL & rHGG"), col=c(rgb(1,0,0,0.5), 
     rgb(0,0,1,0.5)), pt.cex=2, pch=15, cex = .8 )

#------------ NT1D CEL

hist(recgli[which(recgli$in_CEL==1 & recgli$multnom_out=="TxE"),]$nt1v, breaks=35, ylim = c(0, 15),  xlim=c(0,3), col=rgb(1,0,0,0.5), xlab="nt1d value", 
     ylab="", main="distribution of nt1d\n values in CEL vs in NEL")
hist(recgli[which(recgli$in_CEL==1 & recgli$multnom_out=="rHGG"),]$nt1v, breaks=35, ylim = c(0, 15),  xlim=c(0,3), col=rgb(0,0,1,0.5), add=T)
legend("topright", legend=c("in CEL & TxE","in CEL & rHGG"), col=c(rgb(1,0,0,0.5), 
     rgb(0,0,1,0.5)), pt.cex=2, pch=15, cex = .8 )
#------------ NT1D NEL
hist(recgli[which(recgli$in_NEL==1 & recgli$multnom_out=="TxE"),]$nt1d, ylim = c(0, 40),  xlim=c(-10,10), col=rgb(1,0,0,0.5), xlab="nt1d value", 
     ylab="", main="distribution of nt1d\n values in CEL vs in NEL", 
    breaks=seq(min(recgli$nt1d),max(recgli$nt1d),l=3))
hist(recgli[which(recgli$in_NEL==1 & recgli$multnom_out=="rHGG"),]$nt1d, ylim = c(0, 40),  xlim=c(-10,10), col=rgb(0,0,1,0.5), add=T, 
    breaks=seq(min(recgli$nt1d),max(recgli$nt1d),l=3))
legend("topright", legend=c("in NEL & TxE","in NEL & rHGG"), col=c(rgb(1,0,0,0.5), 
     rgb(0,0,1,0.5)), pt.cex=2, pch=15, cex = .8 )
# Out:
# Plot with title “distribution of nfl
#  values in CEL vs in NEL”
# Error in seq.default(min(recgli$nt1d), max(recgli$nt1d), l = 3): 'from' must be a finite number
# Traceback:
#
# 1. hist(recgli[which(recgli$in_NEL == 1 & recgli$multnom_out ==
#  .     "TxE"), ]$nt1d, ylim = c(0, 40), xlim = c(-10, 10), col = rgb(1,
#  .     0, 0, 0.5), xlab = "nt1d value", ylab = "", main = "distribution of nt1d\n values in CEL vs in NEL",
#  .     breaks = seq(min(recgli$nt1d), max(recgli$nt1d), l = 3))
# 2. hist.default(recgli[which(recgli$in_NEL == 1 & recgli$multnom_out ==
#  .     "TxE"), ]$nt1d, ylim = c(0, 40), xlim = c(-10, 10), col = rgb(1,
#  .     0, 0, 0.5), xlab = "nt1d value", ylab = "", main = "distribution of nt1d\n values in CEL vs in NEL",
#  .     breaks = seq(min(recgli$nt1d), max(recgli$nt1d), l = 3))
# 3. seq(min(recgli$nt1d), max(recgli$nt1d), l = 3)
# 4. seq.default(min(recgli$nt1d), max(recgli$nt1d), l = 3)
# 5. stop("'from' must be a finite number")
# ...

# %% [markdown]
# ## 2. Combining anatomical parameters to look at different associations within the GEE model:

# %%
#library(multgee)
recgli$tumor_cell_evaluation = as.character(recgli$tumor_cell_evaluation)
recgli$tumor_cell_evaluation = as.numeric(recgli$tumor_cell_evaluation)
anat.fit = ordLORgee(formula = tumor_cell_evaluation ~ nfl+nt1v, link = "logit", 
                      id = t_number, data = recgli, LORstr = "category.exch")
summary(anat.fit)$coefficients

# %% [markdown]
# ## 3. Using in_CEL as a covariate in anat params using GEE

# %%
anat.cel.fit = anat.fit = ordLORgee(formula = tumor_cell_evaluation ~ nfse+nfl+nt1c+nt1v*in_CEL, link = "logit", 
                      id = t_number, data = recgli, LORstr = "category.exch")

# %%
summary(anat.cel.fit)$coefficients

# %% [markdown]
# ## 4. Using RM ANOVA to use imaging characteristics as the dependent variable, and the TS as independent variable

# %%
library(ez)
table(is.na(recgli$tumor_cell_evaluation))

# %%
nfse.anova.fit = ezANOVA(data = recgli,
                        dv = nfse, 
                        wid = t_number, 
                        within = .(tumor_cell_evaluation))

# %%
nfse.rmaov = aov(nfse ~ tumor_cell_evaluation + Error(t_number/(tumor_cell_evaluation)), data=recgli)
summary(nfse.rmaov)

# %%
nfl.rmaov = aov(nfl ~ tumor_cell_evaluation + Error(t_number/(nfl)), data=recgli)
summary(nfl.rmaov)

# %%
nt1c.rmaov = aov(nt1c ~ tumor_cell_evaluation  + Error(t_number/(tumor_cell_evaluation)), data=recgli)
summary(nt1c.rmaov)

# %%
nt1v.rmaov = aov(nt1v ~ tumor_cell_evaluation  + Error(t_number/tumor_cell_evaluation), data=recgli[!is.na(recgli$nt1v),])
summary(nt1v.rmaov)

# %%
nt1d.rmaov = aov(nt1d ~ tumor_cell_evaluation  + Error(t_number/tumor_cell_evaluation), data=recgli[!is.na(recgli$nt1d),])
summary(nt1d.rmaov)
